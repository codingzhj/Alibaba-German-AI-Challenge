# %% [markdown]
# ##### 对shuffle_50k训练数据进行切分，45k用作训练，剩下的用来验证

# %%
# start tensorflow interactiveSession                              线上   0.68
import tensorflow as tf
import pandas as pd
import numpy as np
from PIL import Image
import random
import h5py

filename = 'E:/Alibaba German AI Challenge/data_process/data_shuffle.npy'

data = np.load(filename)

train = data[:45000]
vali = data[49000:]

print('The shape of train is ',train.shape)
print('The shape of vali is ',vali.shape)

sess = tf.InteractiveSession()

#####################################################     Net Define     ##################################################### 

# weight initialization
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape = shape)
    return tf.Variable(initial)

# convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')
# pooling
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# Create the model
# placeholder
x = tf.placeholder("float", [None, 18432])
y_ = tf.placeholder("float", [None, 17])
keep_prob = tf.placeholder("float")
x_image = tf.reshape(x, [-1, 32, 32, 18])

# first convolutinal layer
w_conv1_1 = weight_variable([3, 3, 18, 64])
b_conv1_1 = bias_variable([64])

w_conv1_2 = weight_variable([3, 3, 64, 64])
b_conv1_2 = bias_variable([64])

h_conv1_1 = tf.nn.relu(conv2d(x_image, w_conv1_1) + b_conv1_1)
h_conv1_2 = tf.nn.relu(conv2d(h_conv1_1, w_conv1_2) + b_conv1_2)
h_pool1 = max_pool_2x2(h_conv1_2)

# second convolutional layer
w_conv2_1 = weight_variable([3, 3, 64, 128])
b_conv2_1 = bias_variable([128])

w_conv2_2 = weight_variable([3, 3, 128, 128])
b_conv2_2 = bias_variable([128])

h_conv2_1 = tf.nn.relu(conv2d(h_pool1, w_conv2_1) + b_conv2_1)
h_conv2_2 = tf.nn.relu(conv2d(h_conv2_1, w_conv2_2) + b_conv2_2)
h_pool2 = max_pool_2x2(h_conv2_2)

# flatten
h_pool2_flat = tf.reshape(h_pool2, [-1, 8*8*128])

# densely connected layer
w_fc1 = weight_variable([8*8*128, 4096])
b_fc1 = bias_variable([4096])

h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, w_fc1) + b_fc1)

# dropout
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# readout layer
w_fc2 = weight_variable([4096, 17])
b_fc2 = bias_variable([17])

y_conv = tf.nn.softmax(tf.matmul(h_fc1_drop, w_fc2) + b_fc2)

# train and evaluate the model
#交叉熵作为损失函数
delta = 1e-7
cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv+delta))
train_step = tf.train.RMSPropOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
sess.run(tf.global_variables_initializer())


#####################################################       Train     ##################################################### 


##随机抽取一部分作为一个mini-batch
def get_batch(data, batch_size):
    sample = random.sample(list(data),batch_size)
    sample = np.array(sample)
    train_x = sample[:,:-17]
    train_y = sample[:,-17:]
    
    return train_x, train_y

Loss = []
vali_Eval = []
train_Eval = []

batch_size = 256
for i in range(30000):
    batch_x,batch_y = get_batch(train,batch_size)
    train_step.run(feed_dict={x:batch_x, y_:batch_y, keep_prob:0.5})
    temp_loss = cross_entropy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
    vali_accuracy = accuracy.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
    train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
    Loss.append(temp_loss)
    vali_Eval.append(vali_accuracy)
    train_Eval.append(train_accuracy)
    if i%200 == 0:
        train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
        print ("step %d, train accuracy %g, vali accuracy %g, train loss %g" %(i, train_accuracy, vali_accuracy, temp_loss))
# Out:
# The shape of train is  (45000, 18449)
# The shape of vali is  (1989, 18449)
# step 0, train accuracy 0.078125, vali accuracy 0.0613374, train loss 3554.09
# step 200, train accuracy 0.179688, vali accuracy 0.171443, train loss 3342.04
# step 400, train accuracy 0.238281, vali accuracy 0.191554, train loss 3112.47
# step 600, train accuracy 0.234375, vali accuracy 0.2182, train loss 3127.49
# step 800, train accuracy 0.230469, vali accuracy 0.208648, train loss 3103.7
# step 1000, train accuracy 0.386719, vali accuracy 0.311212, train loss 2228.68
# step 1200, train accuracy 0.472656, vali accuracy 0.397185, train loss 668.577
# step 1400, train accuracy 0.503906, vali accuracy 0.438411, train loss 563.911
# step 1600, train accuracy 0.558594, vali accuracy 0.490699, train loss 358.859
# step 1800, train accuracy 0.539062, vali accuracy 0.499246, train loss 457.887
# step 2000, train accuracy 0.601562, vali accuracy 0.519859, train loss 359.756
# step 2200, train accuracy 0.628906, vali accuracy 0.536451, train loss 322.066
# step 2400, train accuracy 0.648438, vali accuracy 0.546506, train loss 284.762
# step 2600, train accuracy 0.671875, vali accuracy 0.564103, train loss 316.891
# step 2800, train accuracy 0.6875, vali accuracy 0.577677, train loss 256.027
# step 3000, train accuracy 0.695312, vali accuracy 0.592257, train loss 253.237
# step 3200, train accuracy 0.746094, vali accuracy 0.606838, train loss 247.936
# step 3400, train accuracy 0.695312, vali accuracy 0.577677, train loss 298.912
# step 3600, train accuracy 0.707031, vali accuracy 0.602816, train loss 233.007
# step 3800, train accuracy 0.726562, vali accuracy 0.612871, train loss 218.168
# step 4000, train accuracy 0.714844, vali accuracy 0.60734, train loss 231.339
# step 4200, train accuracy 0.738281, vali accuracy 0.616893, train loss 244.454
# step 4400, train accuracy 0.769531, vali accuracy 0.627954, train loss 210.663
# step 4600, train accuracy 0.730469, vali accuracy 0.631976, train loss 215.287
# step 4800, train accuracy 0.785156, vali accuracy 0.652589, train loss 201.502
# step 5000, train accuracy 0.785156, vali accuracy 0.653092, train loss 194.632
# step 5200, train accuracy 0.824219, vali accuracy 0.66365, train loss 168.892
# step 5400, train accuracy 0.734375, vali accuracy 0.652086, train loss 188.488
# step 5600, train accuracy 0.796875, vali accuracy 0.669683, train loss 166.603
# step 5800, train accuracy 0.804688, vali accuracy 0.6727, train loss 133.581
# step 6000, train accuracy 0.773438, vali accuracy 0.651081, train loss 171.295
# step 6200, train accuracy 0.839844, vali accuracy 0.679739, train loss 128.921
# step 6400, train accuracy 0.800781, vali accuracy 0.665661, train loss 186.744
# step 6600, train accuracy 0.867188, vali accuracy 0.66365, train loss 126.081
# step 6800, train accuracy 0.84375, vali accuracy 0.672197, train loss 138.748
# step 7000, train accuracy 0.828125, vali accuracy 0.673203, train loss 132.791
# step 7200, train accuracy 0.902344, vali accuracy 0.668175, train loss 92.1541
# step 7400, train accuracy 0.867188, vali accuracy 0.675214, train loss 122.926
# step 7600, train accuracy 0.8125, vali accuracy 0.674208, train loss 136.974
# step 7800, train accuracy 0.890625, vali accuracy 0.676219, train loss 115.854
# step 8000, train accuracy 0.855469, vali accuracy 0.665661, train loss 113.429
# step 8200, train accuracy 0.882812, vali accuracy 0.68175, train loss 95.2599
# step 8400, train accuracy 0.929688, vali accuracy 0.69281, train loss 82.9557
# step 8600, train accuracy 0.886719, vali accuracy 0.679236, train loss 85.0487
# step 8800, train accuracy 0.875, vali accuracy 0.695827, train loss 93.0138
# step 9000, train accuracy 0.878906, vali accuracy 0.672197, train loss 101.8
# step 9200, train accuracy 0.902344, vali accuracy 0.68175, train loss 90.1326
# step 9400, train accuracy 0.933594, vali accuracy 0.690297, train loss 105.866
# step 9600, train accuracy 0.90625, vali accuracy 0.70186, train loss 99.9485
# step 9800, train accuracy 0.910156, vali accuracy 0.688788, train loss 77.5373
# step 10000, train accuracy 0.917969, vali accuracy 0.69281, train loss 94.8659
# step 10200, train accuracy 0.929688, vali accuracy 0.69281, train loss 75.955
# step 10400, train accuracy 0.917969, vali accuracy 0.697335, train loss 57.0889
# step 10600, train accuracy 0.941406, vali accuracy 0.700855, train loss 104.941
# step 10800, train accuracy 0.925781, vali accuracy 0.694822, train loss 91.0083
# step 11000, train accuracy 0.882812, vali accuracy 0.665661, train loss 93.7877
# step 11200, train accuracy 0.945312, vali accuracy 0.692308, train loss 69.248
# step 11400, train accuracy 0.933594, vali accuracy 0.682755, train loss 59.7832
# step 11600, train accuracy 0.949219, vali accuracy 0.697838, train loss 67.8875
# step 11800, train accuracy 0.925781, vali accuracy 0.695827, train loss 67.1694
# step 12000, train accuracy 0.910156, vali accuracy 0.706888, train loss 92.6622
# step 12200, train accuracy 0.941406, vali accuracy 0.702866, train loss 50.8137
# step 12400, train accuracy 0.96875, vali accuracy 0.705882, train loss 54.2176
# step 12600, train accuracy 0.949219, vali accuracy 0.700855, train loss 82.4577
# step 12800, train accuracy 0.960938, vali accuracy 0.703871, train loss 36.8227
# step 13000, train accuracy 0.980469, vali accuracy 0.694319, train loss 34.3941
# step 13200, train accuracy 0.941406, vali accuracy 0.70186, train loss 56.4741
# step 13400, train accuracy 0.960938, vali accuracy 0.699346, train loss 53.8086
# step 13600, train accuracy 0.988281, vali accuracy 0.698341, train loss 42.9353
# step 13800, train accuracy 0.96875, vali accuracy 0.693816, train loss 32.7444
# step 14000, train accuracy 0.992188, vali accuracy 0.702363, train loss 23.8207
# step 14200, train accuracy 0.980469, vali accuracy 0.697335, train loss 42.7899
# step 14400, train accuracy 0.992188, vali accuracy 0.71091, train loss 18.9798
# step 14600, train accuracy 0.972656, vali accuracy 0.705882, train loss 26.1773
# step 14800, train accuracy 0.984375, vali accuracy 0.706385, train loss 38.4997
# step 15000, train accuracy 0.972656, vali accuracy 0.699346, train loss 29.7723
# step 15200, train accuracy 0.980469, vali accuracy 0.702866, train loss 22.8163
# step 15400, train accuracy 0.992188, vali accuracy 0.698341, train loss 22.4052
# step 15600, train accuracy 0.992188, vali accuracy 0.708396, train loss 15.8712
# step 15800, train accuracy 0.988281, vali accuracy 0.708899, train loss 46.1253
# step 16000, train accuracy 0.984375, vali accuracy 0.71091, train loss 17.6834
# step 16200, train accuracy 0.960938, vali accuracy 0.699346, train loss 56.0527
# step 16400, train accuracy 0.992188, vali accuracy 0.706385, train loss 14.1409
# step 16600, train accuracy 0.992188, vali accuracy 0.715938, train loss 29.8439
# step 16800, train accuracy 0.980469, vali accuracy 0.699849, train loss 21.3844
# step 17000, train accuracy 0.992188, vali accuracy 0.723479, train loss 14.1982
# step 17200, train accuracy 0.996094, vali accuracy 0.719457, train loss 26.0626
# step 17400, train accuracy 0.992188, vali accuracy 0.712921, train loss 12.7748
# step 17600, train accuracy 0.980469, vali accuracy 0.707391, train loss 25.2595
# step 17800, train accuracy 0.996094, vali accuracy 0.709904, train loss 10.1296
# step 18000, train accuracy 1, vali accuracy 0.70538, train loss 9.81508
# step 18200, train accuracy 0.988281, vali accuracy 0.715435, train loss 31.0963
# step 18400, train accuracy 0.980469, vali accuracy 0.714932, train loss 42.6508
# step 18600, train accuracy 1, vali accuracy 0.706385, train loss 7.06406
# step 18800, train accuracy 0.988281, vali accuracy 0.706888, train loss 27.1766
# step 19000, train accuracy 1, vali accuracy 0.714932, train loss 5.66277
# step 19200, train accuracy 1, vali accuracy 0.715435, train loss 3.928
# step 19400, train accuracy 0.992188, vali accuracy 0.704374, train loss 14.6825
# step 19600, train accuracy 0.988281, vali accuracy 0.718954, train loss 37.1085
# step 19800, train accuracy 0.996094, vali accuracy 0.719457, train loss 5.22553
# step 20000, train accuracy 1, vali accuracy 0.706888, train loss 6.65321
# step 20200, train accuracy 0.996094, vali accuracy 0.694319, train loss 12.4903
# step 20400, train accuracy 0.996094, vali accuracy 0.699849, train loss 6.12391
# step 20600, train accuracy 0.996094, vali accuracy 0.702866, train loss 23.0825
# step 20800, train accuracy 1, vali accuracy 0.718451, train loss 2.34078
# step 21000, train accuracy 0.996094, vali accuracy 0.701357, train loss 11.9652
# step 21200, train accuracy 0.996094, vali accuracy 0.711413, train loss 20.9219
# step 21400, train accuracy 0.992188, vali accuracy 0.709904, train loss 24.2649
# step 21600, train accuracy 0.992188, vali accuracy 0.714932, train loss 19.9634
# step 21800, train accuracy 1, vali accuracy 0.713927, train loss 3.06917
# step 22000, train accuracy 1, vali accuracy 0.71644, train loss 3.25503
# step 22200, train accuracy 0.992188, vali accuracy 0.713424, train loss 34.8738
# step 22400, train accuracy 0.992188, vali accuracy 0.712921, train loss 20.5753
# step 22600, train accuracy 1, vali accuracy 0.720965, train loss 3.16897
# step 22800, train accuracy 1, vali accuracy 0.715938, train loss 3.99126
# step 23000, train accuracy 0.992188, vali accuracy 0.724987, train loss 35.2923
# step 23200, train accuracy 0.996094, vali accuracy 0.715435, train loss 2.8606
# step 23400, train accuracy 1, vali accuracy 0.705882, train loss 6.29641
# step 23600, train accuracy 1, vali accuracy 0.721971, train loss 4.39709
# step 23800, train accuracy 1, vali accuracy 0.720965, train loss 3.17458
# step 24000, train accuracy 1, vali accuracy 0.717446, train loss 1.36186
# step 24200, train accuracy 1, vali accuracy 0.72549, train loss 1.84944
# step 24400, train accuracy 0.996094, vali accuracy 0.724987, train loss 3.24411
# step 24600, train accuracy 0.992188, vali accuracy 0.71996, train loss 34.8853
# step 24800, train accuracy 1, vali accuracy 0.729512, train loss 1.58115
# step 25000, train accuracy 0.996094, vali accuracy 0.724485, train loss 2.75858
# step 25200, train accuracy 1, vali accuracy 0.720965, train loss 1.9655
# step 25400, train accuracy 1, vali accuracy 0.705882, train loss 1.50723
# step 25600, train accuracy 0.996094, vali accuracy 0.722976, train loss 19.0966
# step 25800, train accuracy 1, vali accuracy 0.719457, train loss 1.84747
# step 26000, train accuracy 0.992188, vali accuracy 0.730518, train loss 33.4975
# step 26200, train accuracy 0.988281, vali accuracy 0.695324, train loss 39.911
# step 26400, train accuracy 0.996094, vali accuracy 0.71996, train loss 17.9258
# step 26600, train accuracy 1, vali accuracy 0.723982, train loss 2.604
# step 26800, train accuracy 1, vali accuracy 0.72901, train loss 0.967879
# step 27000, train accuracy 0.988281, vali accuracy 0.71644, train loss 50.4567
# step 27200, train accuracy 0.992188, vali accuracy 0.711916, train loss 34.0671
# step 27400, train accuracy 0.996094, vali accuracy 0.724987, train loss 17.6531
# step 27600, train accuracy 0.996094, vali accuracy 0.720463, train loss 3.1368
# step 27800, train accuracy 1, vali accuracy 0.718451, train loss 1.10072
# step 28000, train accuracy 0.984375, vali accuracy 0.697838, train loss 24.2987
# step 28200, train accuracy 1, vali accuracy 0.712921, train loss 0.881044
# step 28400, train accuracy 1, vali accuracy 0.721468, train loss 1.92093
# step 28600, train accuracy 0.992188, vali accuracy 0.714429, train loss 33.052
# step 28800, train accuracy 0.996094, vali accuracy 0.720463, train loss 17.0236
# step 29000, train accuracy 1, vali accuracy 0.722976, train loss 0.606105
# step 29200, train accuracy 0.992188, vali accuracy 0.723982, train loss 33.4236
# step 29400, train accuracy 0.988281, vali accuracy 0.708899, train loss 20.7412
# step 29600, train accuracy 1, vali accuracy 0.712921, train loss 0.550088
# step 29800, train accuracy 1, vali accuracy 0.706385, train loss 1.50017

# %%
import matplotlib.pyplot as plt

xx = list(range(len(train_Eval)))

plt.figure(figsize = (8,5))
plt.plot(xx,train_Eval, color = 'blue', label = 'train')
plt.plot(xx,vali_Eval, color = 'red', label = 'vali')
plt.title('Eval')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report
pred = y_conv.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
train_val_y = np.argmax(vali[:,-17:],axis = 1)
pred_y = np.argmax(pred, axis = 1)
print (classification_report(train_val_y, pred_y))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.55      0.63      0.59       115
#           1       0.60      0.50      0.55       107
#           2       0.70      0.63      0.66       130
#           3       0.55      0.56      0.55       118
#           4       0.52      0.40      0.46       141
#           5       0.64      0.66      0.65       122
#           6       0.87      0.88      0.88       121
#           7       0.64      0.70      0.67       136
#           8       0.77      0.78      0.77       117
#           9       0.39      0.46      0.42        97
#          10       0.90      0.90      0.90       108
#          11       0.79      0.76      0.78       100
#          12       0.89      0.86      0.87       112
#          13       0.79      0.81      0.80       114
#          14       0.92      0.91      0.91       107
#          15       0.84      0.91      0.87       138
#          16       0.99      0.98      0.99       106
#
# avg / total       0.72      0.72      0.72      1989

# %%
import matplotlib.pyplot as plt

xx = list(range(len(Loss)))

plt.figure(figsize = (8,5))
plt.plot(xx,Loss)
plt.title('Loss')
plt.show()

# %%
import h5py
filename = 'E:/Alibaba German AI Challenge/origin_DATA/round1_test_a_20181109.h5'
f = h5py.File(filename,'r')
test_s1 = f['sen1']
test_s2 = f['sen2']

test = []
for i in range(0,test_s1.shape[0]):
    temp1 = test_s1[i].flatten()
    temp2 = test_s2[i].flatten()
    temp = np.hstack((temp1,temp2))
    test.append(temp)
test = np.array(test)

test_y = np.zeros((test.shape[0],17))

pred = tf.argmax(y_conv, 1)

test_x_0 = test[0:1500]
test_y_0 = test_y[0:1500]
P_0 = pred.eval(feed_dict={x:test_x_0, y_:test_y_0, keep_prob:1.0})

test_x_1 = test[1500:3000]
test_y_1 = test_y[1500:3000]
P_1 = pred.eval(feed_dict={x:test_x_1, y_:test_y_1, keep_prob:1.0})

test_x_2 = test[3000:4500]
test_y_2 = test_y[3000:4500]
P_2 = pred.eval(feed_dict={x:test_x_2, y_:test_y_2, keep_prob:1.0})

test_x_3 = test[4500:]
test_y_3 = test_y[4500:]
P_3 = pred.eval(feed_dict={x:test_x_3, y_:test_y_3, keep_prob:1.0})

P = np.hstack([P_0,P_1,P_2,P_3])

one_hot=tf.one_hot(P,17)
Pred_one_hot = sess.run(one_hot)
Pred_one_hot = Pred_one_hot.astype(np.int32)
out = pd.DataFrame(Pred_one_hot, columns = list(range(17)))
print(out.head())

out.to_csv('4_conv_2_fc_RSMProp.csv', index = False, header = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-37478cbe5799> in <module>()
#       9     temp1 = test_s1[i].flatten()
#      10     temp2 = test_s2[i].flatten()
# ---> 11     temp = np.hstack((temp1,temp2))
#      12     test.append(temp)
#      13 test = np.array(test)
#
# NameError: name 'np' is not defined

# %% [markdown]
# * 损失函数加入正则化项
# * 分类效果并没有提高，说明原先网络结构有待加强
# * 但是从学习曲线可以看出正则化项的加入确实减轻了过拟合

# %%
# start tensorflow interactiveSession                              
import tensorflow as tf
import pandas as pd
import numpy as np
from PIL import Image
import random
import h5py

filename = 'E:/Alibaba German AI Challenge/data_process/data_shuffle.npy'

data = np.load(filename)

train = data[:45000]
vali = data[49000:]

print('The shape of train is ',train.shape)
print('The shape of vali is ',vali.shape)

sess = tf.InteractiveSession()

#####################################################     Net Define     ##################################################### 

# weight initialization
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape = shape)
    return tf.Variable(initial)

# convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')
# pooling
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# Create the model
# placeholder
x = tf.placeholder("float", [None, 18432])
y_ = tf.placeholder("float", [None, 17])
keep_prob = tf.placeholder("float")
x_image = tf.reshape(x, [-1, 32, 32, 18])

# first convolutinal layer
w_conv1_1 = weight_variable([3, 3, 18, 64])
b_conv1_1 = bias_variable([64])

w_conv1_2 = weight_variable([3, 3, 64, 64])
b_conv1_2 = bias_variable([64])

h_conv1_1 = tf.nn.relu(conv2d(x_image, w_conv1_1) + b_conv1_1)
h_conv1_2 = tf.nn.relu(conv2d(h_conv1_1, w_conv1_2) + b_conv1_2)
h_pool1 = max_pool_2x2(h_conv1_2)

# second convolutional layer
w_conv2_1 = weight_variable([3, 3, 64, 128])
b_conv2_1 = bias_variable([128])

w_conv2_2 = weight_variable([3, 3, 128, 128])
b_conv2_2 = bias_variable([128])

h_conv2_1 = tf.nn.relu(conv2d(h_pool1, w_conv2_1) + b_conv2_1)
h_conv2_2 = tf.nn.relu(conv2d(h_conv2_1, w_conv2_2) + b_conv2_2)
h_pool2 = max_pool_2x2(h_conv2_2)

# third convolutional layer
w_conv3_1 = weight_variable([3, 3, 128, 256])
b_conv3_1 = bias_variable([256])

w_conv3_2 = weight_variable([3, 3, 256, 256])
b_conv3_2 = bias_variable([256])

h_conv3_1 = tf.nn.relu(conv2d(h_pool2, w_conv3_1) + b_conv3_1)
h_conv3_2 = tf.nn.relu(conv2d(h_conv3_1, w_conv3_2) + b_conv3_2)
h_pool3 = max_pool_2x2(h_conv3_2)


# flatten
h_pool2_flat = tf.reshape(h_pool3, [-1, 4*4*256])

# densely connected layer
w_fc1 = weight_variable([4*4*256, 8192])
b_fc1 = bias_variable([8192])

h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, w_fc1) + b_fc1)

# dropout
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# readout layer
w_fc3 = weight_variable([8192, 17])
b_fc3 = bias_variable([17])

y_conv = tf.nn.softmax(tf.matmul(h_fc1_drop, w_fc3) + b_fc3)

# train and evaluate the model
#交叉熵作为损失函数
delta = 1e-7
cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv+delta))
train_step = tf.train.RMSPropOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
sess.run(tf.global_variables_initializer())


#####################################################       Train     ##################################################### 


##随机抽取一部分作为一个mini-batch
def get_batch(data, batch_size):
    sample = random.sample(list(data),batch_size)
    sample = np.array(sample)
    train_x = sample[:,:-17]
    train_y = sample[:,-17:]
    
    return train_x, train_y

Loss = []
vali_Eval = []
train_Eval = []

batch_size = 256
for i in range(30000):
    batch_x,batch_y = get_batch(train,batch_size)
    train_step.run(feed_dict={x:batch_x, y_:batch_y, keep_prob:0.5})
    temp_loss = cross_entropy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
    vali_accuracy = accuracy.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
    train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
    Loss.append(temp_loss)
    vali_Eval.append(vali_accuracy)
    train_Eval.append(train_accuracy)
    if i%200 == 0:
        train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
        print ("step %d, train accuracy %g, vali accuracy %g, train loss %g" %(i, train_accuracy, vali_accuracy, temp_loss))
# Out:
# The shape of train is  (45000, 18449)
# The shape of vali is  (1989, 18449)
# step 0, train accuracy 0.0703125, vali accuracy 0.0553042, train loss 3836.11
# step 200, train accuracy 0.0976562, vali accuracy 0.0703871, train loss 3723.28
# step 400, train accuracy 0.1875, vali accuracy 0.106083, train loss 3352.56
# step 600, train accuracy 0.160156, vali accuracy 0.104072, train loss 3465.39
# step 800, train accuracy 0.105469, vali accuracy 0.105581, train loss 3691.04
# step 1000, train accuracy 0.0859375, vali accuracy 0.0975365, train loss 3771.63
# step 1200, train accuracy 0.0859375, vali accuracy 0.104575, train loss 3771.63
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-899ab6240045> in <module>()
#     127     train_step.run(feed_dict={x:batch_x, y_:batch_y, keep_prob:0.5})
#     128     temp_loss = cross_entropy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
# --> 129     vali_accuracy = accuracy.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
#     130     train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
#     131     Loss.append(temp_loss)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\ops.py in eval(self, feed_dict, session)
#     705
#     706     """
# --> 707     return _eval_using_default_session(self, feed_dict, self.graph, session)
#     708
#     709
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\ops.py in _eval_using_default_session(tensors, feed_dict, graph, session)
#    5211                        "the tensor's graph is different from the session's "
#    5212                        "graph.")
# -> 5213   return session.run(tensors, feed_dict)
#    5214
#    5215
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

xx = list(range(len(train_Eval)))

plt.figure(figsize = (8,5))
plt.plot(xx,train_Eval, color = 'blue', label = 'train')
plt.plot(xx,vali_Eval, color = 'red', label = 'vali')
plt.title('Eval')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report
pred = y_conv.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
train_val_y = np.argmax(vali[:,-17:],axis = 1)
pred_y = np.argmax(pred, axis = 1)
print (classification_report(train_val_y, pred_y))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.47      0.60      0.52       115
#           1       0.52      0.42      0.47       107
#           2       0.67      0.66      0.66       130
#           3       0.50      0.49      0.50       118
#           4       0.49      0.48      0.49       141
#           5       0.60      0.60      0.60       122
#           6       0.86      0.93      0.89       121
#           7       0.62      0.70      0.66       136
#           8       0.80      0.73      0.76       117
#           9       0.38      0.35      0.37        97
#          10       0.88      0.91      0.89       108
#          11       0.78      0.76      0.77       100
#          12       0.91      0.79      0.84       112
#          13       0.82      0.81      0.81       114
#          14       0.92      0.91      0.91       107
#          15       0.87      0.91      0.89       138
#          16       0.98      0.98      0.98       106
#
# avg / total       0.71      0.71      0.71      1989

# %%
import matplotlib.pyplot as plt

xx = list(range(len(Loss)))

plt.figure(figsize = (8,5))
plt.plot(xx,Loss)
plt.title('Loss')
plt.show()

# %% [markdown]
# ##### 4层卷积，3层全连接网络

# %%
# start tensorflow interactiveSession                              
import tensorflow as tf
import pandas as pd
import numpy as np
from PIL import Image
import random
import h5py

filename = 'E:/Alibaba German AI Challenge/data_process/data_shuffle.npy'

data = np.load(filename)

train = data[:45000]
vali = data[49000:]

print('The shape of train is ',train.shape)
print('The shape of vali is ',vali.shape)

sess = tf.InteractiveSession()

#####################################################     Net Define     ##################################################### 

# weight initialization
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape = shape)
    return tf.Variable(initial)

# convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')
# pooling
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# Create the model
# placeholder
x = tf.placeholder("float", [None, 18432])
y_ = tf.placeholder("float", [None, 17])
keep_prob = tf.placeholder("float")
x_image = tf.reshape(x, [-1, 32, 32, 18])

# first convolutinal layer
w_conv1_1 = weight_variable([3, 3, 18, 64])
b_conv1_1 = bias_variable([64])

w_conv1_2 = weight_variable([3, 3, 64, 64])
b_conv1_2 = bias_variable([64])

h_conv1_1 = tf.nn.relu(conv2d(x_image, w_conv1_1) + b_conv1_1)
h_conv1_2 = tf.nn.relu(conv2d(h_conv1_1, w_conv1_2) + b_conv1_2)
h_pool1 = max_pool_2x2(h_conv1_2)

# second convolutional layer
w_conv2_1 = weight_variable([3, 3, 64, 128])
b_conv2_1 = bias_variable([128])

w_conv2_2 = weight_variable([3, 3, 128, 128])
b_conv2_2 = bias_variable([128])

h_conv2_1 = tf.nn.relu(conv2d(h_pool1, w_conv2_1) + b_conv2_1)
h_conv2_2 = tf.nn.relu(conv2d(h_conv2_1, w_conv2_2) + b_conv2_2)
h_pool2 = max_pool_2x2(h_conv2_2)

# flatten
h_pool2_flat = tf.reshape(h_pool2, [-1, 8*8*128])

# densely connected layer
w_fc1 = weight_variable([8*8*128, 1024])
b_fc1 = bias_variable([1024])

h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, w_fc1) + b_fc1)

# dropout
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)


# fc_2
w_fc2 = weight_variable([1024, 2048])
b_fc2 = bias_variable([2048])

h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop, w_fc2) + b_fc2)

# dropout
h_fc2_drop = tf.nn.dropout(h_fc2, keep_prob)


# readout layer
w_fc3 = weight_variable([2048, 17])
b_fc3 = bias_variable([17])

y_conv = tf.nn.softmax(tf.matmul(h_fc2_drop, w_fc3) + b_fc3)

# train and evaluate the model
#交叉熵作为损失函数
delta = 1e-7
cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv+delta))
train_step = tf.train.RMSPropOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
sess.run(tf.global_variables_initializer())


#####################################################       Train     ##################################################### 


##随机抽取一部分作为一个mini-batch
def get_batch(data, batch_size):
    sample = random.sample(list(data),batch_size)
    sample = np.array(sample)
    train_x = sample[:,:-17]
    train_y = sample[:,-17:]
    
    return train_x, train_y

Loss = []
vali_Eval = []
train_Eval = []

batch_size = 256
for i in range(30000):
    batch_x,batch_y = get_batch(train,batch_size)
    train_step.run(feed_dict={x:batch_x, y_:batch_y, keep_prob:0.5})
    temp_loss = cross_entropy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
    vali_accuracy = accuracy.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
    train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
    Loss.append(temp_loss)
    vali_Eval.append(vali_accuracy)
    train_Eval.append(train_accuracy)
    if i%200 == 0:
        train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
        print ("step %d, train accuracy %g, vali accuracy %g, train loss %g" %(i, train_accuracy, vali_accuracy, temp_loss))
# Out:
# The shape of train is  (45000, 18449)
# The shape of vali is  (1989, 18449)
# step 0, train accuracy 0.0820312, vali accuracy 0.089995, train loss 3726.43
# step 200, train accuracy 0.125, vali accuracy 0.111111, train loss 3605.3
# step 400, train accuracy 0.117188, vali accuracy 0.122675, train loss 3602.09
# step 600, train accuracy 0.179688, vali accuracy 0.163901, train loss 3381.07
# step 800, train accuracy 0.21875, vali accuracy 0.204625, train loss 3223.62
# step 1000, train accuracy 0.210938, vali accuracy 0.210156, train loss 3248.79
# step 1200, train accuracy 0.203125, vali accuracy 0.212167, train loss 3288.09
# step 1400, train accuracy 0.207031, vali accuracy 0.225239, train loss 3270.18
# step 1600, train accuracy 0.207031, vali accuracy 0.241327, train loss 3271.97
# step 1800, train accuracy 0.222656, vali accuracy 0.240825, train loss 3200.93
# step 2000, train accuracy 0.332031, vali accuracy 0.27099, train loss 2718.29
# step 2200, train accuracy 0.257812, vali accuracy 0.262946, train loss 3062.8
# step 2400, train accuracy 0.261719, vali accuracy 0.276521, train loss 3032.13
# step 2600, train accuracy 0.253906, vali accuracy 0.292107, train loss 3070.27
# step 2800, train accuracy 0.28125, vali accuracy 0.293112, train loss 2962.79
# step 3000, train accuracy 0.265625, vali accuracy 0.293615, train loss 3013.54
# step 3200, train accuracy 0.25, vali accuracy 0.263952, train loss 3081.77
# step 3400, train accuracy 0.277344, vali accuracy 0.282051, train loss 2964.93
# step 3600, train accuracy 0.28125, vali accuracy 0.284565, train loss 2949.62
# step 3800, train accuracy 0.242188, vali accuracy 0.286576, train loss 3126.14
# step 4000, train accuracy 0.320312, vali accuracy 0.299145, train loss 2773.42
# step 4200, train accuracy 0.3125, vali accuracy 0.313223, train loss 2785.45
# step 4400, train accuracy 0.265625, vali accuracy 0.29814, train loss 3010.41
# step 4600, train accuracy 0.308594, vali accuracy 0.310709, train loss 2822.94
# step 4800, train accuracy 0.289062, vali accuracy 0.278532, train loss 2901.12
# step 5000, train accuracy 0.308594, vali accuracy 0.31272, train loss 2819.92
# step 5200, train accuracy 0.324219, vali accuracy 0.334339, train loss 2750.84
# step 5400, train accuracy 0.308594, vali accuracy 0.331322, train loss 2843.7
# step 5600, train accuracy 0.34375, vali accuracy 0.334842, train loss 2704.8
# step 5800, train accuracy 0.308594, vali accuracy 0.318753, train loss 2827.51
# step 6000, train accuracy 0.34375, vali accuracy 0.330317, train loss 2707.86
# step 6200, train accuracy 0.300781, vali accuracy 0.331322, train loss 2882.15
# step 6400, train accuracy 0.328125, vali accuracy 0.340875, train loss 2741.18
# step 6600, train accuracy 0.292969, vali accuracy 0.309201, train loss 2876.14
# step 6800, train accuracy 0.324219, vali accuracy 0.349422, train loss 2754.79
# step 7000, train accuracy 0.316406, vali accuracy 0.326797, train loss 2793.75
# step 7200, train accuracy 0.347656, vali accuracy 0.350427, train loss 2647.76
# step 7400, train accuracy 0.347656, vali accuracy 0.359477, train loss 2630.14
# step 7600, train accuracy 0.300781, vali accuracy 0.355455, train loss 2869.15
# step 7800, train accuracy 0.351562, vali accuracy 0.343891, train loss 2650.62
# step 8000, train accuracy 0.332031, vali accuracy 0.355958, train loss 2756.19
# step 8200, train accuracy 0.261719, vali accuracy 0.361488, train loss 3010.34
# step 8400, train accuracy 0.347656, vali accuracy 0.345902, train loss 2645.54
# step 8600, train accuracy 0.355469, vali accuracy 0.364002, train loss 2588.92
# step 8800, train accuracy 0.382812, vali accuracy 0.37456, train loss 2471.23
# step 9000, train accuracy 0.359375, vali accuracy 0.371041, train loss 2620.03
# step 9200, train accuracy 0.429688, vali accuracy 0.376068, train loss 2289.37
# step 9400, train accuracy 0.390625, vali accuracy 0.36903, train loss 2469.4
# step 9600, train accuracy 0.375, vali accuracy 0.371543, train loss 2503.29
# step 9800, train accuracy 0.320312, vali accuracy 0.36903, train loss 2716.32
# step 10000, train accuracy 0.40625, vali accuracy 0.375063, train loss 2314.34
# step 10200, train accuracy 0.394531, vali accuracy 0.350427, train loss 758.902
# step 10400, train accuracy 0.425781, vali accuracy 0.440925, train loss 595.631
# step 10600, train accuracy 0.507812, vali accuracy 0.475616, train loss 479.401
# step 10800, train accuracy 0.472656, vali accuracy 0.483157, train loss 427.415
# step 11000, train accuracy 0.539062, vali accuracy 0.508798, train loss 377.415
# step 11200, train accuracy 0.554688, vali accuracy 0.494721, train loss 382.281
# step 11400, train accuracy 0.574219, vali accuracy 0.534942, train loss 339.681
# step 11600, train accuracy 0.546875, vali accuracy 0.548014, train loss 330.878
# step 11800, train accuracy 0.648438, vali accuracy 0.56008, train loss 314.192
# step 12000, train accuracy 0.652344, vali accuracy 0.565611, train loss 297.879
# step 12200, train accuracy 0.660156, vali accuracy 0.576672, train loss 261.283
# step 12400, train accuracy 0.648438, vali accuracy 0.581699, train loss 263.94
# step 12600, train accuracy 0.683594, vali accuracy 0.598291, train loss 257.779
# step 12800, train accuracy 0.65625, vali accuracy 0.57265, train loss 257.888
# step 13000, train accuracy 0.652344, vali accuracy 0.589241, train loss 256.505
# step 13200, train accuracy 0.664062, vali accuracy 0.616893, train loss 262.849
# step 13400, train accuracy 0.664062, vali accuracy 0.614882, train loss 267.044
# step 13600, train accuracy 0.636719, vali accuracy 0.591252, train loss 261.643
# step 13800, train accuracy 0.738281, vali accuracy 0.626948, train loss 214.064
# step 14000, train accuracy 0.664062, vali accuracy 0.61086, train loss 261.861
# step 14200, train accuracy 0.707031, vali accuracy 0.637506, train loss 221.611
# step 14400, train accuracy 0.683594, vali accuracy 0.631976, train loss 252.128
# step 14600, train accuracy 0.691406, vali accuracy 0.632981, train loss 225.794
# step 14800, train accuracy 0.738281, vali accuracy 0.639517, train loss 201.227
# step 15000, train accuracy 0.734375, vali accuracy 0.657114, train loss 208.081
# step 15200, train accuracy 0.746094, vali accuracy 0.653595, train loss 221.404
# step 15400, train accuracy 0.6875, vali accuracy 0.629462, train loss 223.686
# step 15600, train accuracy 0.691406, vali accuracy 0.647059, train loss 214.374
# step 15800, train accuracy 0.679688, vali accuracy 0.643539, train loss 213.221
# step 16000, train accuracy 0.699219, vali accuracy 0.657617, train loss 218.553
# step 16200, train accuracy 0.695312, vali accuracy 0.656611, train loss 217.436
# step 16400, train accuracy 0.738281, vali accuracy 0.680744, train loss 200.793
# step 16600, train accuracy 0.730469, vali accuracy 0.682252, train loss 205.09
# step 16800, train accuracy 0.730469, vali accuracy 0.679739, train loss 202.293
# step 17000, train accuracy 0.726562, vali accuracy 0.677225, train loss 207.099
# step 17200, train accuracy 0.707031, vali accuracy 0.667672, train loss 214.081
# step 17400, train accuracy 0.742188, vali accuracy 0.68175, train loss 196.859
# step 17600, train accuracy 0.828125, vali accuracy 0.684766, train loss 162.39
# step 17800, train accuracy 0.777344, vali accuracy 0.681247, train loss 155.678
# step 18000, train accuracy 0.75, vali accuracy 0.677225, train loss 187.788
# step 18200, train accuracy 0.769531, vali accuracy 0.689794, train loss 180.625
# step 18400, train accuracy 0.785156, vali accuracy 0.689794, train loss 144.948
# step 18600, train accuracy 0.730469, vali accuracy 0.694822, train loss 202.266
# step 18800, train accuracy 0.824219, vali accuracy 0.69633, train loss 173.269
# step 19000, train accuracy 0.796875, vali accuracy 0.685269, train loss 169.342
# step 19200, train accuracy 0.792969, vali accuracy 0.696833, train loss 157.42
# step 19400, train accuracy 0.832031, vali accuracy 0.706888, train loss 141.195
# step 19600, train accuracy 0.824219, vali accuracy 0.708899, train loss 142.565
# step 19800, train accuracy 0.832031, vali accuracy 0.712418, train loss 137.357
# step 20000, train accuracy 0.800781, vali accuracy 0.690297, train loss 148.682
# step 20200, train accuracy 0.800781, vali accuracy 0.713424, train loss 154.403
# step 20400, train accuracy 0.820312, vali accuracy 0.71091, train loss 154.242
# step 20600, train accuracy 0.855469, vali accuracy 0.71644, train loss 129.682
# step 20800, train accuracy 0.8125, vali accuracy 0.70538, train loss 139.221
# step 21000, train accuracy 0.808594, vali accuracy 0.70538, train loss 148.621
# step 21200, train accuracy 0.816406, vali accuracy 0.700352, train loss 130.48
# step 21400, train accuracy 0.828125, vali accuracy 0.720463, train loss 135.42
# step 21600, train accuracy 0.808594, vali accuracy 0.714932, train loss 137.137
# step 21800, train accuracy 0.824219, vali accuracy 0.699346, train loss 152.853
# step 22000, train accuracy 0.820312, vali accuracy 0.714932, train loss 147.408
# step 22200, train accuracy 0.839844, vali accuracy 0.711916, train loss 125.075
# step 22400, train accuracy 0.824219, vali accuracy 0.722474, train loss 137.936
# step 22600, train accuracy 0.839844, vali accuracy 0.723982, train loss 128.514
# step 22800, train accuracy 0.855469, vali accuracy 0.718954, train loss 121.203
# step 23000, train accuracy 0.816406, vali accuracy 0.725993, train loss 134.033
# step 23200, train accuracy 0.894531, vali accuracy 0.720463, train loss 138.005
# step 23400, train accuracy 0.871094, vali accuracy 0.724987, train loss 126.248
# step 23600, train accuracy 0.886719, vali accuracy 0.720463, train loss 101.826
# step 23800, train accuracy 0.882812, vali accuracy 0.728004, train loss 100.428
# step 24000, train accuracy 0.882812, vali accuracy 0.721468, train loss 105.886
# step 24200, train accuracy 0.835938, vali accuracy 0.723479, train loss 137.549
# step 24400, train accuracy 0.859375, vali accuracy 0.705882, train loss 107.191
# step 24600, train accuracy 0.828125, vali accuracy 0.707893, train loss 134.573
# step 24800, train accuracy 0.867188, vali accuracy 0.729512, train loss 108.445
# step 25000, train accuracy 0.902344, vali accuracy 0.736048, train loss 91.8014
# step 25200, train accuracy 0.917969, vali accuracy 0.730518, train loss 90.1493
# step 25400, train accuracy 0.902344, vali accuracy 0.717446, train loss 94.8901
# step 25600, train accuracy 0.898438, vali accuracy 0.733534, train loss 85.6717
# step 25800, train accuracy 0.839844, vali accuracy 0.725993, train loss 103.429
# step 26000, train accuracy 0.863281, vali accuracy 0.737054, train loss 119.166
# step 26200, train accuracy 0.871094, vali accuracy 0.736551, train loss 117.987
# step 26400, train accuracy 0.878906, vali accuracy 0.72901, train loss 94.8143
# step 26600, train accuracy 0.917969, vali accuracy 0.735043, train loss 79.5359
# step 26800, train accuracy 0.875, vali accuracy 0.726496, train loss 110.089
# step 27000, train accuracy 0.890625, vali accuracy 0.743087, train loss 85.3524
# step 27200, train accuracy 0.894531, vali accuracy 0.746606, train loss 90.1098
# step 27400, train accuracy 0.882812, vali accuracy 0.74359, train loss 86.6766
# step 27600, train accuracy 0.898438, vali accuracy 0.735043, train loss 124.586
# step 27800, train accuracy 0.867188, vali accuracy 0.725993, train loss 111.755
# step 28000, train accuracy 0.910156, vali accuracy 0.748617, train loss 72.7638
# step 28200, train accuracy 0.929688, vali accuracy 0.74912, train loss 70.6538
# step 28400, train accuracy 0.890625, vali accuracy 0.74359, train loss 93.0285
# step 28600, train accuracy 0.898438, vali accuracy 0.730518, train loss 99.7821
# step 28800, train accuracy 0.910156, vali accuracy 0.728507, train loss 80.3589
# step 29000, train accuracy 0.882812, vali accuracy 0.741076, train loss 101.475
# step 29200, train accuracy 0.886719, vali accuracy 0.734037, train loss 80.9374
# step 29400, train accuracy 0.925781, vali accuracy 0.75264, train loss 72.9933
# step 29600, train accuracy 0.902344, vali accuracy 0.751634, train loss 77.2814
# step 29800, train accuracy 0.886719, vali accuracy 0.730015, train loss 81.0108

# %%
import matplotlib.pyplot as plt

xx = list(range(len(train_Eval)))

plt.figure(figsize = (8,5))
plt.plot(xx,train_Eval, color = 'blue', label = 'train')
plt.plot(xx,vali_Eval, color = 'red', label = 'vali')
plt.title('Eval')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

xx = list(range(len(Loss)))

plt.figure(figsize = (8,5))
plt.plot(xx,Loss)
plt.title('Loss')
plt.show()

# %%
from sklearn.metrics import classification_report
pred = y_conv.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
train_val_y = np.argmax(vali[:,-17:],axis = 1)
pred_y = np.argmax(pred, axis = 1)
print (classification_report(train_val_y, pred_y))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.60      0.62      0.61       115
#           1       0.57      0.53      0.55       107
#           2       0.67      0.72      0.69       130
#           3       0.51      0.69      0.59       118
#           4       0.64      0.50      0.56       141
#           5       0.70      0.66      0.68       122
#           6       0.82      0.88      0.85       121
#           7       0.73      0.73      0.73       136
#           8       0.79      0.75      0.77       117
#           9       0.46      0.42      0.44        97
#          10       0.96      0.84      0.90       108
#          11       0.76      0.86      0.81       100
#          12       0.83      0.80      0.82       112
#          13       0.84      0.79      0.81       114
#          14       0.88      0.93      0.90       107
#          15       0.85      0.84      0.84       138
#          16       0.97      0.98      0.98       106
#
# avg / total       0.74      0.74      0.74      1989

# %% [markdown]
# ##### 5层卷积，3层全连接网络

# %%
# start tensorflow interactiveSession                              
import tensorflow as tf
import pandas as pd
import numpy as np
from PIL import Image
import random
import h5py

filename = 'E:/Alibaba German AI Challenge/data_process/data_shuffle.npy'

data = np.load(filename)

train = data[:49000, 8192:]
vali = data[49000:, 8192:]

print('The shape of train is ',train.shape)
print('The shape of vali is ',vali.shape)

sess = tf.InteractiveSession()

#####################################################     Net Define     ##################################################### 

# weight initialization
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape = shape)
    return tf.Variable(initial)

# convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')
# pooling
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# Create the model
# placeholder
x = tf.placeholder("float", [None, 10240])
y_ = tf.placeholder("float", [None, 17])
keep_prob = tf.placeholder("float")
x_image = tf.reshape(x, [-1, 32, 32, 10])

# first convolutinal layer
w_conv1_1 = weight_variable([3, 3, 10, 64])
b_conv1_1 = bias_variable([64])

w_conv1_2 = weight_variable([3, 3, 64, 64])
b_conv1_2 = bias_variable([64])

h_conv1_1 = tf.nn.relu(conv2d(x_image, w_conv1_1) + b_conv1_1)
h_conv1_2 = tf.nn.relu(conv2d(h_conv1_1, w_conv1_2) + b_conv1_2)
h_pool1 = max_pool_2x2(h_conv1_2)

# second convolutional layer
w_conv2_1 = weight_variable([3, 3, 64, 128])
b_conv2_1 = bias_variable([128])

w_conv2_2 = weight_variable([3, 3, 128, 128])
b_conv2_2 = bias_variable([128])

h_conv2_1 = tf.nn.relu(conv2d(h_pool1, w_conv2_1) + b_conv2_1)
h_conv2_2 = tf.nn.relu(conv2d(h_conv2_1, w_conv2_2) + b_conv2_2)
h_pool2 = max_pool_2x2(h_conv2_2)


# third conv layer

w_conv3_1 = weight_variable([3, 3, 128, 256])
b_conv3_1 = bias_variable([256])

h_conv3_1 = tf.nn.relu(conv2d(h_pool2, w_conv3_1) + b_conv3_1)
h_pool3 = max_pool_2x2(h_conv3_1)



# flatten
h_pool2_flat = tf.reshape(h_pool3, [-1, 4*4*256])

# densely connected layer
w_fc1 = weight_variable([4*4*256, 1024])
b_fc1 = bias_variable([1024])

h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, w_fc1) + b_fc1)

# dropout
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# fc_2
w_fc2 = weight_variable([1024, 2048])
b_fc2 = bias_variable([2048])

h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop, w_fc2) + b_fc2)

# dropout
h_fc2_drop = tf.nn.dropout(h_fc2, keep_prob)

# readout layer
w_fc3 = weight_variable([2048, 17])
b_fc3 = bias_variable([17])

y_conv = tf.nn.softmax(tf.matmul(h_fc2_drop, w_fc3) + b_fc3)

# train and evaluate the model
#交叉熵作为损失函数
delta = 1e-7
learning_rate = 1e-5
#cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv+delta))+tf.norm(w_fc3)
cross_entropy = -tf.reduce_sum(y_*tf.log(y_conv+delta))
train_step = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float"))
sess.run(tf.global_variables_initializer())


#####################################################       Train     ##################################################### 


##随机抽取一部分作为一个mini-batch
def get_batch(data, batch_size):
    sample = random.sample(list(data),batch_size)
    sample = np.array(sample)
    train_x = sample[:,:-17]
    train_y = sample[:,-17:]
    
    return train_x, train_y

Loss = []
vali_Eval = []
train_Eval = []

batch_size = 256
step_num = 1000000
for i in range(step_num):
    batch_x,batch_y = get_batch(train,batch_size)
    train_step.run(feed_dict={x:batch_x, y_:batch_y, keep_prob:0.5})
    if i%200 == 0:
        temp_loss = cross_entropy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
        vali_accuracy = accuracy.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
        train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
        Loss.append(temp_loss)
        vali_Eval.append(vali_accuracy)
        train_Eval.append(train_accuracy)
        train_accuracy = accuracy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
        print ("step %d, train accuracy %g, vali accuracy %g, train loss %g" %(i, train_accuracy, vali_accuracy, temp_loss))
# Out:
# The shape of train is  (49000, 10257)
# The shape of vali is  (1989, 10257)
# step 0, train accuracy 0.0585938, vali accuracy 0.0608346, train loss 3882.35
# step 200, train accuracy 0.0859375, vali accuracy 0.0608346, train loss 3715.41
# step 400, train accuracy 0.121094, vali accuracy 0.114128, train loss 3626.57
# step 600, train accuracy 0.117188, vali accuracy 0.129211, train loss 3612.52
# step 800, train accuracy 0.15625, vali accuracy 0.166415, train loss 3481.51
# step 1000, train accuracy 0.164062, vali accuracy 0.165913, train loss 3449.27
# step 1200, train accuracy 0.148438, vali accuracy 0.166918, train loss 3498.35
# step 1400, train accuracy 0.21875, vali accuracy 0.205631, train loss 3197.2
# step 1600, train accuracy 0.242188, vali accuracy 0.223731, train loss 3077.1
# step 1800, train accuracy 0.253906, vali accuracy 0.231775, train loss 3056
# step 2000, train accuracy 0.242188, vali accuracy 0.264957, train loss 3022.24
# step 2200, train accuracy 0.289062, vali accuracy 0.276018, train loss 2873.34
# step 2400, train accuracy 0.332031, vali accuracy 0.304173, train loss 2695.63
# step 2600, train accuracy 0.414062, vali accuracy 0.322775, train loss 2295.7
# step 2800, train accuracy 0.335938, vali accuracy 0.33082, train loss 2658.16
# step 3000, train accuracy 0.390625, vali accuracy 0.356963, train loss 2220.98
# step 3200, train accuracy 0.410156, vali accuracy 0.369532, train loss 2199.39
# step 3400, train accuracy 0.398438, vali accuracy 0.388135, train loss 2226.53
# step 3600, train accuracy 0.394531, vali accuracy 0.403218, train loss 2302.63
# step 3800, train accuracy 0.375, vali accuracy 0.406737, train loss 2277.95
# step 4000, train accuracy 0.40625, vali accuracy 0.418301, train loss 2160.01
# step 4200, train accuracy 0.441406, vali accuracy 0.419306, train loss 1955.95
# step 4400, train accuracy 0.445312, vali accuracy 0.426848, train loss 1257.01
# step 4600, train accuracy 0.40625, vali accuracy 0.377577, train loss 513.122
# step 4800, train accuracy 0.386719, vali accuracy 0.362494, train loss 524.848
# step 5000, train accuracy 0.339844, vali accuracy 0.368527, train loss 519.895
# step 5200, train accuracy 0.359375, vali accuracy 0.399698, train loss 545.447
# step 5400, train accuracy 0.351562, vali accuracy 0.393665, train loss 530.818
# step 5600, train accuracy 0.40625, vali accuracy 0.392157, train loss 498.235
# step 5800, train accuracy 0.449219, vali accuracy 0.387129, train loss 472.761
# step 6000, train accuracy 0.460938, vali accuracy 0.407743, train loss 440.169
# step 6200, train accuracy 0.429688, vali accuracy 0.402715, train loss 466.108
# step 6400, train accuracy 0.441406, vali accuracy 0.416792, train loss 450.107
# step 6600, train accuracy 0.472656, vali accuracy 0.42735, train loss 448.265
# step 6800, train accuracy 0.425781, vali accuracy 0.423328, train loss 467.461
# step 7000, train accuracy 0.417969, vali accuracy 0.442936, train loss 464.168
# step 7200, train accuracy 0.453125, vali accuracy 0.441931, train loss 409.173
# step 7400, train accuracy 0.523438, vali accuracy 0.449472, train loss 419.397
# step 7600, train accuracy 0.558594, vali accuracy 0.458522, train loss 369.629
# step 7800, train accuracy 0.496094, vali accuracy 0.46003, train loss 430.239
# step 8000, train accuracy 0.472656, vali accuracy 0.472599, train loss 437.771
# step 8200, train accuracy 0.472656, vali accuracy 0.475113, train loss 409.018
# step 8400, train accuracy 0.4375, vali accuracy 0.486174, train loss 450.905
# step 8600, train accuracy 0.480469, vali accuracy 0.488688, train loss 451.205
# step 8800, train accuracy 0.542969, vali accuracy 0.487682, train loss 380.986
# step 9000, train accuracy 0.480469, vali accuracy 0.495726, train loss 404.384
# step 9200, train accuracy 0.570312, vali accuracy 0.506787, train loss 369.877
# step 9400, train accuracy 0.539062, vali accuracy 0.506787, train loss 369.311
# step 9600, train accuracy 0.507812, vali accuracy 0.502262, train loss 441.377
# step 9800, train accuracy 0.554688, vali accuracy 0.508798, train loss 337.338
# step 10000, train accuracy 0.519531, vali accuracy 0.504274, train loss 371.081
# step 10200, train accuracy 0.53125, vali accuracy 0.517345, train loss 367.397
# step 10400, train accuracy 0.523438, vali accuracy 0.514329, train loss 365.054
# step 10600, train accuracy 0.585938, vali accuracy 0.524384, train loss 349.252
# step 10800, train accuracy 0.558594, vali accuracy 0.510307, train loss 370.414
# step 11000, train accuracy 0.570312, vali accuracy 0.53092, train loss 361.582
# step 11200, train accuracy 0.636719, vali accuracy 0.524384, train loss 307.095
# step 11400, train accuracy 0.605469, vali accuracy 0.531926, train loss 320.305
# step 11600, train accuracy 0.550781, vali accuracy 0.523881, train loss 364.736
# step 11800, train accuracy 0.53125, vali accuracy 0.543992, train loss 355.325
# step 12000, train accuracy 0.496094, vali accuracy 0.527401, train loss 386.027
# step 12200, train accuracy 0.570312, vali accuracy 0.534942, train loss 332.465
# step 12400, train accuracy 0.519531, vali accuracy 0.548517, train loss 370.503
# step 12600, train accuracy 0.558594, vali accuracy 0.537959, train loss 324.945
# step 12800, train accuracy 0.585938, vali accuracy 0.53997, train loss 314.928
# step 13000, train accuracy 0.597656, vali accuracy 0.541981, train loss 338.967
# step 13200, train accuracy 0.609375, vali accuracy 0.558069, train loss 307.492
# step 13400, train accuracy 0.53125, vali accuracy 0.559578, train loss 335.723
# step 13600, train accuracy 0.609375, vali accuracy 0.56008, train loss 290.253
# step 13800, train accuracy 0.53125, vali accuracy 0.554047, train loss 345.02
# step 14000, train accuracy 0.628906, vali accuracy 0.561589, train loss 303.492
# step 14200, train accuracy 0.578125, vali accuracy 0.565611, train loss 327.111
# step 14400, train accuracy 0.589844, vali accuracy 0.568627, train loss 330.165
# step 14600, train accuracy 0.609375, vali accuracy 0.571141, train loss 317.711
# step 14800, train accuracy 0.558594, vali accuracy 0.574158, train loss 329.691
# step 15000, train accuracy 0.542969, vali accuracy 0.581699, train loss 356.568
# step 15200, train accuracy 0.636719, vali accuracy 0.57265, train loss 299.559
# step 15400, train accuracy 0.695312, vali accuracy 0.578683, train loss 260.01
# step 15600, train accuracy 0.589844, vali accuracy 0.581197, train loss 297.23
# step 15800, train accuracy 0.636719, vali accuracy 0.579688, train loss 296.943
# step 16000, train accuracy 0.648438, vali accuracy 0.581197, train loss 301.058
# step 16200, train accuracy 0.589844, vali accuracy 0.58371, train loss 303.633
# step 16400, train accuracy 0.628906, vali accuracy 0.589241, train loss 289.408
# step 16600, train accuracy 0.636719, vali accuracy 0.597285, train loss 301.797
# step 16800, train accuracy 0.640625, vali accuracy 0.582202, train loss 296.903
# step 17000, train accuracy 0.609375, vali accuracy 0.591755, train loss 298.059
# step 17200, train accuracy 0.601562, vali accuracy 0.587733, train loss 302.569
# step 17400, train accuracy 0.652344, vali accuracy 0.600804, train loss 268.471
# step 17600, train accuracy 0.621094, vali accuracy 0.598793, train loss 302.554
# step 17800, train accuracy 0.632812, vali accuracy 0.603318, train loss 286.611
# step 18000, train accuracy 0.664062, vali accuracy 0.598291, train loss 256.166
# step 18200, train accuracy 0.648438, vali accuracy 0.60181, train loss 266.749
# step 18400, train accuracy 0.695312, vali accuracy 0.596782, train loss 242.751
# step 18600, train accuracy 0.695312, vali accuracy 0.600302, train loss 250.791
# step 18800, train accuracy 0.679688, vali accuracy 0.607843, train loss 244.391
# step 19000, train accuracy 0.644531, vali accuracy 0.594771, train loss 253.609
# step 19200, train accuracy 0.628906, vali accuracy 0.607843, train loss 262.353
# step 19400, train accuracy 0.652344, vali accuracy 0.61086, train loss 250.142
# step 19600, train accuracy 0.648438, vali accuracy 0.609351, train loss 242.758
# step 19800, train accuracy 0.722656, vali accuracy 0.609854, train loss 235.734
# step 20000, train accuracy 0.699219, vali accuracy 0.618904, train loss 240.915
# step 20200, train accuracy 0.648438, vali accuracy 0.60734, train loss 262.715
# step 20400, train accuracy 0.71875, vali accuracy 0.61639, train loss 237.657
# step 20600, train accuracy 0.628906, vali accuracy 0.618904, train loss 254.386
# step 20800, train accuracy 0.671875, vali accuracy 0.600302, train loss 251.677
# step 21000, train accuracy 0.699219, vali accuracy 0.61991, train loss 234.343
# step 21200, train accuracy 0.652344, vali accuracy 0.625943, train loss 253.82
# step 21400, train accuracy 0.648438, vali accuracy 0.625943, train loss 253.446
# step 21600, train accuracy 0.65625, vali accuracy 0.619407, train loss 247.628
# step 21800, train accuracy 0.671875, vali accuracy 0.622926, train loss 248.976
# step 22000, train accuracy 0.636719, vali accuracy 0.621418, train loss 265.541
# step 22200, train accuracy 0.644531, vali accuracy 0.623429, train loss 258.814
# step 22400, train accuracy 0.675781, vali accuracy 0.63449, train loss 228.287
# step 22600, train accuracy 0.6875, vali accuracy 0.636501, train loss 251.355
# step 22800, train accuracy 0.6875, vali accuracy 0.634992, train loss 227.161
# step 23000, train accuracy 0.703125, vali accuracy 0.634992, train loss 251.435
# step 23200, train accuracy 0.691406, vali accuracy 0.63449, train loss 223.906
# step 23400, train accuracy 0.695312, vali accuracy 0.638009, train loss 238.392
# step 23600, train accuracy 0.667969, vali accuracy 0.627954, train loss 237.737
# step 23800, train accuracy 0.746094, vali accuracy 0.641528, train loss 213.941
# step 24000, train accuracy 0.707031, vali accuracy 0.640523, train loss 227.553
# step 24200, train accuracy 0.652344, vali accuracy 0.630468, train loss 262.438
# step 24400, train accuracy 0.703125, vali accuracy 0.641026, train loss 217.152
# step 24600, train accuracy 0.671875, vali accuracy 0.64907, train loss 235.334
# step 24800, train accuracy 0.742188, vali accuracy 0.647059, train loss 211.742
# step 25000, train accuracy 0.691406, vali accuracy 0.640523, train loss 250.614
# step 25200, train accuracy 0.632812, vali accuracy 0.652589, train loss 244.012
# step 25400, train accuracy 0.75, vali accuracy 0.653092, train loss 204.542
# step 25600, train accuracy 0.707031, vali accuracy 0.648567, train loss 213.812
# step 25800, train accuracy 0.6875, vali accuracy 0.652086, train loss 221.625
# step 26000, train accuracy 0.644531, vali accuracy 0.645551, train loss 237.643
# step 26200, train accuracy 0.730469, vali accuracy 0.655103, train loss 203.587
# step 26400, train accuracy 0.738281, vali accuracy 0.655103, train loss 201.986
# step 26600, train accuracy 0.726562, vali accuracy 0.650075, train loss 207.092
# step 26800, train accuracy 0.722656, vali accuracy 0.655606, train loss 207.129
# step 27000, train accuracy 0.691406, vali accuracy 0.657617, train loss 227.092
# step 27200, train accuracy 0.691406, vali accuracy 0.659125, train loss 220.421
# step 27400, train accuracy 0.726562, vali accuracy 0.661136, train loss 202.855
# step 27600, train accuracy 0.703125, vali accuracy 0.660131, train loss 210.974
# step 27800, train accuracy 0.726562, vali accuracy 0.659628, train loss 182.086
# step 28000, train accuracy 0.710938, vali accuracy 0.665158, train loss 204.751
# step 28200, train accuracy 0.710938, vali accuracy 0.662645, train loss 206.777
# step 28400, train accuracy 0.75, vali accuracy 0.673705, train loss 203.67
# step 28600, train accuracy 0.742188, vali accuracy 0.666667, train loss 191.079
# step 28800, train accuracy 0.722656, vali accuracy 0.661136, train loss 202.756
# step 29000, train accuracy 0.683594, vali accuracy 0.670186, train loss 231.587
# step 29200, train accuracy 0.699219, vali accuracy 0.677728, train loss 210.039
# step 29400, train accuracy 0.742188, vali accuracy 0.673705, train loss 180.812
# step 29600, train accuracy 0.714844, vali accuracy 0.6727, train loss 223.249
# step 29800, train accuracy 0.742188, vali accuracy 0.671192, train loss 205.524
# step 30000, train accuracy 0.714844, vali accuracy 0.677225, train loss 210.192
# step 30200, train accuracy 0.722656, vali accuracy 0.677728, train loss 211.272
# step 30400, train accuracy 0.738281, vali accuracy 0.679236, train loss 201.459
# step 30600, train accuracy 0.714844, vali accuracy 0.676219, train loss 193.257
# step 30800, train accuracy 0.671875, vali accuracy 0.68175, train loss 224.284
# step 31000, train accuracy 0.730469, vali accuracy 0.681247, train loss 185.207
# step 31200, train accuracy 0.773438, vali accuracy 0.673705, train loss 176.502
# step 31400, train accuracy 0.699219, vali accuracy 0.674711, train loss 218.101
# step 31600, train accuracy 0.738281, vali accuracy 0.681247, train loss 196.276
# step 31800, train accuracy 0.734375, vali accuracy 0.675214, train loss 180.543
# step 32000, train accuracy 0.726562, vali accuracy 0.695324, train loss 190.758
# step 32200, train accuracy 0.695312, vali accuracy 0.679236, train loss 221.439
# step 32400, train accuracy 0.695312, vali accuracy 0.68175, train loss 202.34
# step 32600, train accuracy 0.777344, vali accuracy 0.68728, train loss 182.028
# step 32800, train accuracy 0.738281, vali accuracy 0.679236, train loss 191.126
# step 33000, train accuracy 0.738281, vali accuracy 0.686275, train loss 208.577
# step 33200, train accuracy 0.738281, vali accuracy 0.679739, train loss 205.813
# step 33400, train accuracy 0.703125, vali accuracy 0.680241, train loss 216.769
# step 33600, train accuracy 0.753906, vali accuracy 0.684263, train loss 176.37
# step 33800, train accuracy 0.730469, vali accuracy 0.683258, train loss 191.276
# step 34000, train accuracy 0.710938, vali accuracy 0.695827, train loss 200.945
# step 34200, train accuracy 0.769531, vali accuracy 0.688788, train loss 183.876
# step 34400, train accuracy 0.765625, vali accuracy 0.689291, train loss 178.44
# step 34600, train accuracy 0.796875, vali accuracy 0.693313, train loss 166.209
# step 34800, train accuracy 0.753906, vali accuracy 0.686275, train loss 190.326
# step 35000, train accuracy 0.753906, vali accuracy 0.696833, train loss 187.57
# step 35200, train accuracy 0.757812, vali accuracy 0.697335, train loss 167.613
# step 35400, train accuracy 0.761719, vali accuracy 0.699346, train loss 184.733
# step 35600, train accuracy 0.714844, vali accuracy 0.703369, train loss 204.56
# step 35800, train accuracy 0.761719, vali accuracy 0.695324, train loss 174.579
# step 36000, train accuracy 0.765625, vali accuracy 0.699346, train loss 164.105
# step 36200, train accuracy 0.773438, vali accuracy 0.702363, train loss 176.383
# step 36400, train accuracy 0.789062, vali accuracy 0.700352, train loss 177.891
# step 36600, train accuracy 0.730469, vali accuracy 0.696833, train loss 200.692
# step 36800, train accuracy 0.777344, vali accuracy 0.704877, train loss 165.941
# step 37000, train accuracy 0.796875, vali accuracy 0.69633, train loss 162.012
# step 37200, train accuracy 0.734375, vali accuracy 0.700352, train loss 182.945
# step 37400, train accuracy 0.769531, vali accuracy 0.706888, train loss 182.694
# step 37600, train accuracy 0.8125, vali accuracy 0.704374, train loss 161.728
# step 37800, train accuracy 0.75, vali accuracy 0.702866, train loss 182.612
# step 38000, train accuracy 0.785156, vali accuracy 0.704374, train loss 171.161
# step 38200, train accuracy 0.769531, vali accuracy 0.702866, train loss 164.782
# step 38400, train accuracy 0.746094, vali accuracy 0.712418, train loss 183.329
# step 38600, train accuracy 0.722656, vali accuracy 0.704877, train loss 191.754
# step 38800, train accuracy 0.789062, vali accuracy 0.703369, train loss 170.537
# step 39000, train accuracy 0.75, vali accuracy 0.713424, train loss 179.286
# step 39200, train accuracy 0.738281, vali accuracy 0.713927, train loss 183.477
# step 39400, train accuracy 0.796875, vali accuracy 0.712418, train loss 158.154
# step 39600, train accuracy 0.714844, vali accuracy 0.704877, train loss 182.721
# step 39800, train accuracy 0.753906, vali accuracy 0.709402, train loss 201.118
# step 40000, train accuracy 0.824219, vali accuracy 0.705882, train loss 151.886
# step 40200, train accuracy 0.816406, vali accuracy 0.711413, train loss 176.447
# step 40400, train accuracy 0.804688, vali accuracy 0.712418, train loss 144.839
# step 40600, train accuracy 0.765625, vali accuracy 0.713424, train loss 174.045
# step 40800, train accuracy 0.757812, vali accuracy 0.718954, train loss 159.318
# step 41000, train accuracy 0.792969, vali accuracy 0.708396, train loss 160.784
# step 41200, train accuracy 0.761719, vali accuracy 0.704374, train loss 168.611
# step 41400, train accuracy 0.789062, vali accuracy 0.71644, train loss 157.091
# step 41600, train accuracy 0.828125, vali accuracy 0.719457, train loss 150.3
# step 41800, train accuracy 0.742188, vali accuracy 0.718451, train loss 180.036
# step 42000, train accuracy 0.804688, vali accuracy 0.721971, train loss 159.168
# step 42200, train accuracy 0.769531, vali accuracy 0.712418, train loss 165.747
# step 42400, train accuracy 0.773438, vali accuracy 0.723982, train loss 163.733
# step 42600, train accuracy 0.765625, vali accuracy 0.721468, train loss 159.89
# step 42800, train accuracy 0.785156, vali accuracy 0.720463, train loss 155.532
# step 43000, train accuracy 0.789062, vali accuracy 0.729512, train loss 158.835
# step 43200, train accuracy 0.785156, vali accuracy 0.72901, train loss 154.856
# step 43400, train accuracy 0.769531, vali accuracy 0.726496, train loss 174.404
# step 43600, train accuracy 0.8125, vali accuracy 0.719457, train loss 146.313
# step 43800, train accuracy 0.796875, vali accuracy 0.730015, train loss 155.728
# step 44000, train accuracy 0.78125, vali accuracy 0.722976, train loss 155.261
# step 44200, train accuracy 0.765625, vali accuracy 0.732026, train loss 166.612
# step 44400, train accuracy 0.777344, vali accuracy 0.718954, train loss 159.573
# step 44600, train accuracy 0.808594, vali accuracy 0.723479, train loss 155.953
# step 44800, train accuracy 0.820312, vali accuracy 0.722474, train loss 147.36
# step 45000, train accuracy 0.800781, vali accuracy 0.73454, train loss 145.725
# step 45200, train accuracy 0.792969, vali accuracy 0.722474, train loss 164.274
# step 45400, train accuracy 0.789062, vali accuracy 0.720965, train loss 148.947
# step 45600, train accuracy 0.757812, vali accuracy 0.734037, train loss 172.142
# step 45800, train accuracy 0.773438, vali accuracy 0.72901, train loss 158.865
# step 46000, train accuracy 0.8125, vali accuracy 0.728004, train loss 145.957
# step 46200, train accuracy 0.789062, vali accuracy 0.733534, train loss 156.977
# step 46400, train accuracy 0.8125, vali accuracy 0.733032, train loss 155.147
# step 46600, train accuracy 0.773438, vali accuracy 0.734037, train loss 153.108
# step 46800, train accuracy 0.808594, vali accuracy 0.731021, train loss 145.239
# step 47000, train accuracy 0.78125, vali accuracy 0.724987, train loss 158.427
# step 47200, train accuracy 0.78125, vali accuracy 0.733534, train loss 164.807
# step 47400, train accuracy 0.785156, vali accuracy 0.737557, train loss 159.1
# step 47600, train accuracy 0.796875, vali accuracy 0.737054, train loss 143.693
# step 47800, train accuracy 0.792969, vali accuracy 0.737054, train loss 166.719
# step 48000, train accuracy 0.769531, vali accuracy 0.738562, train loss 168.713
# step 48200, train accuracy 0.847656, vali accuracy 0.73454, train loss 126.403
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-bfdf3cb1ec8c> in <module>()
#     136 for i in range(step_num):
#     137     batch_x,batch_y = get_batch(train,batch_size)
# --> 138     train_step.run(feed_dict={x:batch_x, y_:batch_y, keep_prob:0.5})
#     139     if i%200 == 0:
#     140         temp_loss = cross_entropy.eval(feed_dict={x:batch_x, y_:batch_y, keep_prob:1.0})
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\ops.py in run(self, feed_dict, session)
#    2397         none, the default session will be used.
#    2398     """
# -> 2399     _run_using_default_session(self, feed_dict, self.graph, session)
#    2400
#    2401 _gradient_registry = registry.Registry("gradient")
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\framework\ops.py in _run_using_default_session(operation, feed_dict, graph, session)
#    5246                        "the operation's graph is different from the session's "
#    5247                        "graph.")
# -> 5248   session.run(operation, feed_dict)
#    5249
#    5250
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# E:\Anaconda3\envs\tensorflow-gpu\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt

xx = list(range(len(train_Eval)))

plt.figure(figsize = (8,5))
plt.plot(xx,train_Eval, color = 'blue', label = 'train')
plt.plot(xx,vali_Eval, color = 'red', label = 'vali')
plt.title('Eval')
plt.legend()
plt.show()

# %%
from sklearn.metrics import classification_report
pred = y_conv.eval(feed_dict={x:vali[:,:-17], y_:vali[:,-17:], keep_prob:1.0})
train_val_y = np.argmax(vali[:,-17:],axis = 1)
pred_y = np.argmax(pred, axis = 1)
print (classification_report(train_val_y, pred_y))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.70      0.64      0.67       115
#           1       0.54      0.66      0.60       107
#           2       0.65      0.60      0.62       130
#           3       0.54      0.64      0.58       118
#           4       0.55      0.48      0.52       141
#           5       0.65      0.69      0.67       122
#           6       0.92      0.85      0.88       121
#           7       0.69      0.76      0.72       136
#           8       0.80      0.76      0.78       117
#           9       0.57      0.54      0.55        97
#          10       0.87      0.87      0.87       108
#          11       0.68      0.78      0.73       100
#          12       0.83      0.75      0.79       112
#          13       0.90      0.81      0.85       114
#          14       0.89      0.88      0.88       107
#          15       0.88      0.86      0.87       138
#          16       0.99      0.98      0.99       106
#
# avg / total       0.74      0.74      0.74      1989

# %%
import matplotlib.pyplot as plt

xx = list(range(len(Loss)))

plt.figure(figsize = (8,5))
plt.plot(xx,Loss)
plt.title('Loss')
plt.show()
